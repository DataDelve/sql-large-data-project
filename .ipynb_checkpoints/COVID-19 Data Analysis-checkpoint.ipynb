# %% [markdown]
# <h2>COVID-19 Data Analysis</h2>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <p>Data file is in CSV format.</p>
# <p>File size is 9.21 GB.</p>
# <p>Since this file is too large, below, I count the number of lines and split the file into multiple files.</p>

# %%
f = open("COVID-19_Case_Surveillance_Public_Use_Data_with_Geography.csv", "r")

# %%
for count, line in enumerate(f):
    pass

# %%
print(count)
# Out:
# 69664983

# %%
chunk_size = 20000000

# %%
def write_chunk(part, lines):
    with open("three-parts_data_part_" + str(part) + ".csv", "w") as f_out:
        f_out.write(header)
        f_out.writelines(lines)

# %%
with open("COVID-19_Case_Surveillance_Public_Use_Data_with_Geography.csv", "r") as f:
    count = 0
    header = f.readline()
    lines = []
    for line in f:
        count += 1
        lines.append(line)
        if count % chunk_size == 0:
            write_chunk(count // chunk_size, lines)
            lines = []
    # write remainder
    if len(lines) > 0:
        write_chunk((count // chunk_size) + 1, lines)

# %%
df = pd.read_csv("three-parts_data_part_1.csv")

# %%
df.head()
# Out:
#   case_month res_state  state_fips_code res_county  county_fips_code  \
# 0    2021-01        MA             25.0    SUFFOLK           25025.0
# 1    2021-02        NJ             34.0      ESSEX           34013.0
# 2    2021-05        NY             36.0       ERIE           36029.0
# 3    2020-07        NV             32.0      CLARK           32003.0
# 4    2020-07        MA             25.0      ESSEX           25009.0
#
#         age_group     sex   race            ethnicity  \
# 0  18 to 49 years  Female    NaN                  NaN
# 1  50 to 64 years    Male    NaN                  NaN
# 2  18 to 49 years    Male  White  Non-Hispanic/Latino
# 3  18 to 49 years  Female  White  Non-Hispanic/Latino
# 4  18 to 49 years  Female  White      Hispanic/Latino
#
#    case_positive_specimen_interval  case_onset_interval               process  \
# 0                              NaN                  NaN               Missing
# 1                              NaN                  0.0               Missing
# 2                              NaN                  0.0               Missing
# 3                              0.0                  0.0  Routine surveillance
# 4                              NaN                  NaN               Missing
#
#   exposure_yn             current_status symptom_status  hosp_yn   icu_yn  \
# 0     Missing  Laboratory-confirmed case        Missing  Missing  Missing
# 1     Missing  Laboratory-confirmed case    Symptomatic      Yes  Missing
# 2     Missing  Laboratory-confirmed case    Symptomatic       No  Missing
# 3     Missing  Laboratory-confirmed case    Symptomatic       No  Unknown
# 4     Missing  Laboratory-confirmed case        Missing  Missing  Missing
#
#   death_yn underlying_conditions_yn
# 0  Missing                      NaN
# 1       No                      NaN
# 2       No                      NaN
# 3       No                      NaN
# 4       No                      NaN

# %%
# Out:
#          case_month res_state res_county  county_fips_code       age_group  \
# 0           2021-01        MA    SUFFOLK           25025.0  18 to 49 years
# 1           2021-02        NJ      ESSEX           34013.0  50 to 64 years
# 2           2021-05        NY       ERIE           36029.0  18 to 49 years
# 3           2020-07        NV      CLARK           32003.0  18 to 49 years
# 4           2020-07        MA      ESSEX           25009.0  18 to 49 years
# ...             ...       ...        ...               ...             ...
# 19999995    2020-09        PA       YORK           42133.0  50 to 64 years
# 19999996    2021-12        MI    ALLEGAN           26005.0    0 - 17 years
# 19999997    2022-01        WI      BROWN           55009.0    0 - 17 years
# 19999998    2020-07        UT      CACHE           49005.0  18 to 49 years
# 19999999    2021-05        WI       DANE           55025.0  18 to 49 years
#
#              sex   race            ethnicity  case_positive_specimen_interval  \
# 0         Female    NaN                  NaN                              NaN
# 1           Male    NaN                  NaN                              NaN
# 2           Male  White  Non-Hispanic/Latino                              NaN
# 3         Female  White  Non-Hispanic/Latino                              0.0
# 4         Female  White      Hispanic/Latino                              NaN
# ...          ...    ...                  ...                              ...
# 19999995  Female  White  Non-Hispanic/Latino                              1.0
# 19999996    Male  White  Non-Hispanic/Latino                              NaN
# 19999997    Male  White  Non-Hispanic/Latino                              NaN
# 19999998    Male  White  Non-Hispanic/Latino                              0.0
# 19999999    Male  White  Non-Hispanic/Latino                              NaN
#
#           case_onset_interval               process exposure_yn  \
# 0                         NaN               Missing     Missing
# 1                         0.0               Missing     Missing
# 2                         0.0               Missing     Missing
# 3                         0.0  Routine surveillance     Missing
# 4                         NaN               Missing     Missing
# ...                       ...                   ...         ...
# 19999995                  0.0               Missing     Missing
# 19999996                  0.0               Missing     Missing
# 19999997                  0.0               Missing     Missing
# 19999998                  0.0   Clinical evaluation         Yes
# 19999999                  0.0               Missing     Missing
#
#                      current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0         Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 1         Laboratory-confirmed case    Symptomatic      Yes  Missing       No
# 2         Laboratory-confirmed case    Symptomatic       No  Missing       No
# 3         Laboratory-confirmed case    Symptomatic       No  Unknown       No
# 4         Laboratory-confirmed case        Missing  Missing  Missing       No
# ...                             ...            ...      ...      ...      ...
# 19999995  Laboratory-confirmed case    Symptomatic  Unknown  Unknown  Unknown
# 19999996  Laboratory-confirmed case    Symptomatic       No  Missing       No
# 19999997  Laboratory-confirmed case    Symptomatic       No  Missing  Unknown
# 19999998  Laboratory-confirmed case    Symptomatic       No       No       No
# 19999999  Laboratory-confirmed case    Symptomatic       No  Missing       No
#
#          underlying_conditions_yn
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 19999995                      NaN
# 19999996                      NaN
# 19999997                      NaN
# 19999998                      Yes
# 19999999                      NaN
#
# [20000000 rows x 18 columns]

# %%
df.drop("county_fips_code", axis = 1, inplace = True)

# %%
df.drop("state_fips_code", axis = 1, inplace = True)

# %%
df.to_csv("exported-data-1.csv")
